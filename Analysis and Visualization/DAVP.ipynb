# %%
#Importing required python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#Reading csv file
file_path = 'E:\Dataset.csv'
s = pd.read_csv(file_path)
print(s)

#Inserting the Dataset into a DataFrame

sports=pd.DataFrame(s)
s=s.fillna(0)
print(sports)



#Plotting a Bar Graph

x=np.array(["cricket","Kabaddi","Table Tennis","Badminton","Football","Chess","Carroms","Kho-Kho"])
y=np.array([26,11,7,11,8,19,17,13])
plt.bar(x,y, color='black')
plt.grid()
plt.show()


#Plotting a Pie Charts


x=np.array(["Cricket","Kabaddi","Table Tennis","Badminton","Football","Chess","Carroms","Kho-Kho"])
y= np.array([24,9,5,9,6,17,15,11])
plt.title("Participation in Each Sport")
plt.pie(y, labels=x, startangle=90)
plt.show()


#Plotting Graph 

x=np.array(["Cricket","Kabaddi","Table Tennis","Badminton","Football","Chess","Carroms","Kho-Kho"])
y= np.array([24,9,5,9,6,17,15,11])
plt.plot ( x,y, marker= 'o', mfc='r', ms=11 )
plt.show()
# Out:
#     S.NO NAME OF THE STUDENT
# 0      1      S. ASHOK KUMAR
# 1      2     Y. NARAYANA RAO
# 2      3        P. SAI VIKAS
# 3      4           R. SURESH
# 4      5          E. AYYAPPA
# ..   ...                 ...
# 124    8      M. SAI KRISHNA
# 125    9     N. PAVAN KALYAN
# 126   10          S.K. TALHA
# 127   11  M.N. SREERAM SURAJ
# 128   12          V.HARSHITH
#
# [129 rows x 2 columns]
#     S.NO NAME OF THE STUDENT
# 0      1      S. ASHOK KUMAR
# 1      2     Y. NARAYANA RAO
# 2      3        P. SAI VIKAS
# 3      4           R. SURESH
# 4      5          E. AYYAPPA
# ..   ...                 ...
# 124    8      M. SAI KRISHNA
# 125    9     N. PAVAN KALYAN
# 126   10          S.K. TALHA
# 127   11  M.N. SREERAM SURAJ
# 128   12          V.HARSHITH
#
# [129 rows x 2 columns]
